# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#imports from sklearn library
from sklearn import datasets
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler,PolynomialFeatures,LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression,Ridge, Lasso
from sklearn.svm import LinearSVR, SVR, NuSVR
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error,r2_score

from sklearn.ensemble import  RandomForestRegressor,IsolationForest

# %%
data = pd.read_csv(r"C:\Users\Dell\Documents\GitHub\Machine-Learning\Machine_Learning\01. week1_project\chip_dataset.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4945 entries, 0 to 4944
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product                4945 non-null   object
#  1   Type                   4945 non-null   object
#  2   Release Date           4746 non-null   object
#  3   Process Size (nm)      4945 non-null   object
#  4   TDP (W)                4508 non-null   object
#  5   Die Size (mm^2)        4593 non-null   object
#  6   Transistors (million)  4390 non-null   object
#  7   Freq (GHz)             4508 non-null   float64
#  8   Foundry                4330 non-null   object
#  9   Vendor                 4945 non-null   object
#  10  FP16 GFLOPS            800 non-null    float64
#  11  FP32 GFLOPS            1685 non-null   float64
#  12  FP64 GFLOPS            1278 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 502.4+ KB

# %%
data.head()
# Out:
#            Product Type Release Date Process Size (nm) TDP (W)  \
# 0  AMD Athlon 1000  CPU       6/5/00               180      54
# 1  AMD Athlon 1000  CPU     10/31/00               180      54
# 2  AMD Athlon 1100  CPU      8/14/00               180      60
# 3  AMD Athlon 1133  CPU     10/31/00               180      63
# 4  AMD Athlon 1200  CPU     10/31/00               180      66
#
#   Die Size (mm^2) Transistors (million)  Freq (GHz) Foundry Vendor  \
# 0             120                    37      1000.0     NaN    AMD
# 1             120                    37      1000.0     NaN    AMD
# 2             120                    37      1100.0     NaN    AMD
# 3             120                    37      1133.0     NaN    AMD
# 4             120                    37      1200.0     NaN    AMD
#
#    FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %% [markdown]
# ## Transform temporal data to their corrrect format (date time)

# %%
data["Release Date"] = pd.to_datetime(data["Release Date"], format="%m/%d/%y")

# %% [markdown]
# ## Explore the missingness in the dataset for categorical and numerical data

# %%
categorical_cols = ["Product", "Type","Process Size (nm)","Foundry","Vendor"]  # List of categorical columns
for col in categorical_cols:
    missing_values = data[col].isnull().sum()
    print(f"Missing values in {col}: {missing_values}")
# Out:
# Missing values in Product: 0
# Missing values in Type: 0
# Missing values in Process Size (nm): 0
# Missing values in Foundry: 0
# Missing values in Vendor: 0

# %%
numerical_cols = ["Freq (GHz)", "FP16 GFLOPS","FP32 GFLOPS","FP64 GFLOPS","Die Size (mm^2)","Transistors (million)","TDP (W)"]  # List of numerical columns
for col in numerical_cols:
    missing_values = data[col].isnull().sum()
    print(f"Missing values in {col}: {missing_values}")
# Out:
# Missing values in Freq (GHz): 0
# Missing values in FP16 GFLOPS: 0
# Missing values in FP32 GFLOPS: 0
# Missing values in FP64 GFLOPS: 0
# Missing values in Die Size (mm^2): 0
# Missing values in Transistors (million): 0
# Missing values in TDP (W): 0

# %%
numerical_cols
# Out:
# ['Freq (GHz)',
#  'FP16 GFLOPS',
#  'FP32 GFLOPS',
#  'FP64 GFLOPS',
#  'Die Size (mm^2)',
#  'Transistors (million)']

# %% [markdown]
# ## How i was testing my data

# %%
data["Product"].nunique()
# Out:
# 4567

# %%
data["Type"].unique()
# Out:
# array(['CPU', 'GPU'], dtype=object)

# %%
data["Process Size (nm)"].unique()
# Out:
# array(['180', '90', '130', '65', '45', '32', '40', '22', '28', '14', '12',
#        '10', '7', '16', '6', '5', '4', '250', '150', '110', '0', '80',
#        '55', '14+', '14++', '14+++', '20', '10+', '8'], dtype=object)

# %%
data["TDP (W)"].unique()
# Out:
# array(['54', '60', '63', '66', '38', '40', '43', '45', '47', '50', '52',
#        '30', '55', '58', '29', '31', '25', '68', '70', '72', '51', '59',
#        '89', '67', '49', '64', '53', '62', '61', '69', '110', '84', '27',
#        '36', '8', '9', '65', '74', '73', '92', '21', '26', '32', '35',
#        '10', '79', '77', '82', '85', '76', '24', '97', '104', '88', '115',
#        '103', '135', '83', '95', '22', '130', '125', '119', '120', '75',
#        '15', '80', '150', '3', '19', '44', '105', '5', '4', '1', '2',
#        '17', '7', '140', '13', '6', '28', '300', '18', '100', '225', '37',
#        '12', '270', '245', '90', '160', '165', '145', '215', '230', '260',
#        '170', '180', '112', '91', '200', '250', '320', '205', '255', '71',
#        '155', '280', '127', '350', '400', '240', '380', '185', '235',
#        '195', '190', '265', '220', '210', '290', '360', '175', '340',
#        '330', '385', '46', nan, 'unknown', '23', '11', '57', '33', '48',
#        '81', '101', '111', '41', '42', '113', '203', '86', '108', '109',
#        '96', '143', '16', '20', '159', '106', '14', '171', '520', '800',
#        '56', '151', '118', '286', '182', '236', '204', '189', '640',
#        '600', '188', '294', '141', '219', '315', '289', '34', '208',
#        '228', '133', '244', '142', '39', '254', '186', '138', '365',
#        '116', '231', '238', '247', '900', '375', '274', '500', '122',
#        '275', '239', '580', '148', '295', '345', '475', '132', '184',
#        '107', '176', '335', '355', '450', '285', '750', '263', '405',
#        '2400', '425', '700'], dtype=object)

# %%
data["Die Size (mm^2)"].unique()
# Out:
# array(['120', '129', '217', '80', '106', '375', '84', '193', '83', '115',
#        '199', '156', '150', '101', '144', '146', '109', '56', '131', nan,
#        '269', '100', '237', '112', '135', '125', '90', '206', '2x 81',
#        '213', '235', '126', '220', '103', '111', '143', '2x 143', '435',
#        '77', '230', '103.1', '183', '101.3', '285', '66', '2x 107',
#        '25.96', '26', '76', '82', '107', '81', '2x 82', '263', '63',
#        '117', '169', '258', '96', '296', '346', '87', '65', '684', '239',
#        '228', '75', '315', '316', '149', '216', '246', '2x 315', '94',
#        '118', '133', '160', '350', '177', '257', '264', '341', '245',
#        '50', '356', '622', '182', '122', '46', '250', '124', '171', '456',
#        '192', '2x 213', '93', '123', '154', '484', '209.8', '210',
#        '4x 213', '70.52', '180.3', '148', '74', '2x 74', '4x 74', '180',
#        '8x 74', '177.5', '195', '308', '190', '146.1', '215', '276',
#        '8x 81', '4x 72', '8x 72', '12x 72', '71', '208', '2x 71', '4x 81',
#        '163', '73', '2x 73', '4x 73', '8x 73', '137', '178', '4x 71',
#        '8x 71', '12x 71', '2x 763', 'unknown', '88', '64', '279', '68',
#        '128', '142', '188', '97', '174', '218', '92', '98', '130', '91',
#        '121', '207', '240', '281', '289', '297', '110', '225', '287',
#        '288', '181', '222', '333', '196', '86', '352', '95', '153', '420',
#        '85', '67', '127', '324', '60', '256', '260', '576', '470', '186',
#        '104', '282', '166', '334', '57', '59', '255', '389', '168', '62',
#        '116', '238', '332', '529', '520', '212', '227', '79', '6', '720',
#        '221', '294', '114', '561', '348', '438', '363', '366', '398',
#        '596', '601', '322', '209', '232', '132', '200', '314', '610',
#        '471', '495', '359', '815', '331', '397', '445', '545', '754',
#        '158', '251', '284', '750', '197', '360', '826', '628', '392',
#        '724', '335', '157', '406', '496', '379', '609', '1017', '204',
#        '1280', '159', '814'], dtype=object)

# %%
data["Transistors (million)"].unique()
# Out:
# array(['37', nan, '42', '44', '28', '140', '69', '105', '233', '154',
#        '63', '55', '125', '16', '106', '178', '77', '286', '114', '155',
#        '151', '169', '230', '376', '200', '227', '81', '167', '291',
#        '293', '582', '1328', '122', '450', '176', '820', '463', '47',
#        '228', '420', '410', '274', '456', '731', '94', '300', '758',
#        '234', '123', '774', '904', '2300', '382', '1170', '384', '1178',
#        '1200', '2400', '504', '624', '1160', '2270', '1303', '1480',
#        '1400', '5000', '960', '1300', '1860', '2800', '2411', '2600',
#        '5690', '3200', '1750', '5960', '3100', '3400', '7200', '8000',
#        '4800', '9600', '4950', '19200', '3800', '4940', '7600', '15200',
#        '9800', '4150', '8300', '30400', '4050', '10700', '10600', '33200',
#        '26280', '52560', '78840', '6570', '8850', '13140', '16600',
#        '8875', '17750', '35500', '90160', '135240', '71000', '20900',
#        '25000', '17840', '14', '30', 'unknown', '51', '10', '25', '20',
#        '15', '54', '60', '57', '110', '36', '80', '29', '117', '76', '45',
#        '82', '135', '90', '160', '107', '75', '120', '146', '222', '312',
#        '157', '232', '198', '302', '278', '177', '112', '681', '666', '8',
#        '390', '720', '180', '378', '181', '210', '289', '754', '314',
#        '956', '514', '242', '505', '627', '826', '959', '1040', '2154',
#        '260', '486', '727', '370', '292', '1700', '2640', '372', '585',
#        '1950', '3000', '716', '4313', '1500', '880', '392', '1270',
#        '2540', '3540', '7080', '950', '2080', '6200', '1020', '11', '690',
#        '2410', '930', '1550', '5200', '1870', '7100', '8900', '2940',
#        '5700', '3300', '4400', '15300', '11800', '2200', '12500', '7000',
#        '1800', '2000', '21100', '13230', '10800', '13600', '18600',
#        '9000', '6400', '10300', '4700', '6600', '25600', '26800', '54200',
#        '28300', '17400', '58200', '11060', '17200', '8700', '12000',
#        '13100', '5400', '57700', '21700', '22000', '45900', '35800',
#        '76300', '25390', '153000', '13300', '28100', '11500', '100000',
#        '18900', '22900', '80000'], dtype=object)

# %%
data["Foundry"].unique()
# Out:
# array([nan, 'Intel', 'TSMC', 'Fujitsu', 'GlobalFoundries', 'IBM', 'NEC',
#        'UMC', 'Sony', 'Samsung', 'Renesas'], dtype=object)

# %%
data["Foundry"].nunique()
# Out:
# 10

# %%
data["Vendor"].unique()
# Out:
# array(['AMD', 'Intel', 'VIA', '3dfx', 'ATI', 'Matrox', 'NVIDIA', 'Sony',
#        'XGI'], dtype=object)

# %%
data["Freq (GHz)"].nunique()
# Out:
# 540

# %%
data["Freq (GHz)"].unique()
# Out:
# array([1000., 1100., 1133., 1200.,  600.,  650.,  700.,  750.,  800.,
#         850.,  900.,  950.,  667., 1400., 1500.,  866.,  933., 1300.,
#        1333., 2000., 2200., 2400., 1467., 1533., 1600., 1733., 1800.,
#        1583., 1667., 1750., 1833., 1700., 1900., 3060., 1266., 2133.,
#        2083., 2167., 2250., 2100., 2261., 2527., 2600., 2660., 2793.,
#        2394., 2790., 1917., 2333., 1862., 1867., 2300., 2700., 2800.,
#        2667., 3067., 3200., 3000., 2500., 3066., 1992., 2533., 2530.,
#        2930., 3334., 3600., 2933., 3400., 3800., 3466., 2260., 2833.,
#        1866., 2166., 2666., 1066., 3166., 3333., 3500., 3100., 1860.,
#        1073., 1067., 1334., 2267., 2534., 2900., 2266., 3300., 1834.,
#        1877., 1650., 3900., 4000., 1053., 1250., 1910., 1463., 1580.,
#        2170., 3700., 1238., 2160., 1830., 4200., 4300., 4100., 3050.,
#        4050., 3250., 3850., 2750., 2450., 4700., 4500., 3350., 2050.,
#        2550., 2650., 3550.,  166.,   nan,  143.,  120.,  162.,  148.,
#         133.,  125.,  200.,  175.,  250.,  105.,  147.,  275.,  230.,
#         150.,  300.,  280.,  183.,  290.,  187.,  240.,  233.,  277.,
#         260.,  325.,  324.,  160.,  100.,  220.,  270.,  398.,  378.,
#         412.,  320.,  144.,  222.,  400.,  297.,  500.,  380.,  390.,
#         190.,  235.,  425.,  475.,  450.,  350.,  295.,  199.,  391.,
#         493.,  491.,  333.,  375.,  520.,  507.,  540.,  525.,  594.,
#         480.,  590.,  336.,  430.,  225.,  440.,  371.,  419.,  550.,
#         575.,  625.,  243.,  560.,  513.,  576.,  360.,  777.,  688.,
#         680.,  460.,  722.,  601.,  743.,  668.,  635.,  587.,  473.,
#         630.,  567.,  675.,  470.,  612.,  580.,  459.,  725.,  660.,
#         796.,  669.,  640.,  533.,  530.,  602.,  648.,  610.,  503.,
#         519.,  730.,  589.,  738.,  535.,  606.,  615.,  506.,  702.,
#         518.,  633.,  585.,  825.,  488.,  276.,  775.,  880.,  690.,
#         720.,  810.,  570.,  783.,  790.,  608.,  701.,  732.,  772.,
#         405.,  574.,  508.,  444.,  593.,  598.,  840.,  715.,  925.,
#         523.,  672.,  871.,  753.,  779.,  736.,  552.,  620.,  416.,
#         651.,  760.,  975.,  327.,  496.,  686.,  875.,  902.,  797.,
#         709., 1058.,  928.,  980.,  823.,  915.,  654.,  719.,  706.,
#         745.,  670., 1075.,  424.,  497., 1050.,  947.,  853.,  311.,
#         954.,  967.,  837.,  926., 1085., 1006.,  863.,  784.,  771.,
#         889.,  824.,  930.,  920.,  758.,  780.,  626.,  860.,  940.,
#         918., 1002., 1018.,  723., 1082.,  874.,  993.,  628.,  924.,
#        1127., 1038.,  705.,  756.,  851., 1046., 1150.,  876.,  693.,
#         562.,  735., 1030., 1070.,  970.,  955.,  943.,  834.,  557.,
#        1071., 1087., 1024., 1176., 1064., 1098.,  773.,  861.,  962.,
#         872.,  948.,  911., 1090., 1120.,  855., 1125.,  713., 1188.,
#         891.,  914., 1033.,  965.,  795., 1354., 1291., 1506., 1405.,
#        1443., 1607., 1557., 1304., 1029., 1140.,  988., 1417., 1025.,
#        1328., 1190.,  886., 1303., 1124.,  907., 1096., 1243., 1440.,
#         852., 1138., 1019., 1175., 1168., 1257., 1156., 1247., 1406.,
#        1382., 1172., 1228., 1493., 1063., 1215., 1277., 1481.,  978.,
#        1109.,  937., 1469.,  991., 1076., 1202., 1164., 1329., 1430.,
#         384., 1012., 1245., 1312., 1004.,  815.,  931., 1275., 1152.,
#        1392., 1410., 1515., 1350.,  854., 1582., 1132., 1139., 1418.,
#        1455., 1316., 1177., 1005., 1620., 1305., 1395., 1230., 1297.,
#        1290., 1380., 1574., 1187., 1295., 1670., 1375., 1074., 1465.,
#        1605., 1680., 1366., 1485., 1020., 1530., 1519.,  960., 1470.,
#         885.,  945., 1110., 1035.,  765., 1575., 1260.,  935., 2233.,
#         822., 1744., 1448., 1327., 1130., 1825., 2075., 1565., 1095.,
#        1065., 1531.,  747., 1365., 1185., 2331., 1224., 2068., 1626.,
#        1968., 1941., 2321., 1489., 2116., 1320.,  832.,  712.,  817.,
#         682.,  495., 1170.,  420., 1512., 2039., 1923., 2310., 2055.,
#        2150., 1855., 1550., 1950., 1155., 1740., 1545., 1552.,  757.,
#         622.,  652., 1237., 1560., 2205., 2235.,  607.,  510.,  435.,
#        1080., 1720., 1452., 1437., 1287., 2505., 1920., 2280., 1335.,
#        2325., 1665., 1590., 1635., 2070., 1425., 1042., 1980., 2340.,
#        2295.])

# %%
data["FP16 GFLOPS"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 4940     6021.0
# 4941    35480.0
# 4942    44100.0
# 4943    52220.0
# 4944    71810.0
# Name: FP16 GFLOPS, Length: 4945, dtype: float64

# %%
data["FP32 GFLOPS"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 4940     6021.0
# 4941    35480.0
# 4942    44100.0
# 4943    52220.0
# 4944    71810.0
# Name: FP32 GFLOPS, Length: 4945, dtype: float64

# %%
data["FP64 GFLOPS"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 4940      94.08
# 4941     554.40
# 4942     689.00
# 4943     816.00
# 4944    1122.00
# Name: FP64 GFLOPS, Length: 4945, dtype: float64

# %% [markdown]
# ## Develop a strategy to deal with the missing values, i.e deletion, imputation by mean or mode etc, whilst providing rationale for your approach. And Drop non-consequntial fields

# %%
data["Process Size (nm)"] = data["Process Size (nm)"].str.replace("[^0-9]", " ", regex=True)  # Remove non-numeric characters puts a space
data["Process Size (nm)"] = pd.to_numeric(data["Process Size (nm)"], errors="coerce")         # Remove non-numeric values and replace them with NaN
data["Process Size (nm)"] = data["Process Size (nm)"].fillna(0)                               #replace nan with 0            
data["Process Size (nm)"] = data["Process Size (nm)"].astype(int)                             #converting to int

# %%
data["TDP (W)"] = data["TDP (W)"].replace("unknown",np.nan) #convert the unknown to nan       
data["TDP (W)"] = data["TDP (W)"].fillna(0)  
data["TDP (W)"] = data["TDP (W)"].astype(int)

# %%
data["Die Size (mm^2)"] = data["Die Size (mm^2)"].replace("unknown",np.nan)
data["Die Size (mm^2)"] = pd.to_numeric(data["Die Size (mm^2)"], errors="coerce")   #i lost some values
data["Die Size (mm^2)"] = data["Die Size (mm^2)"].fillna(0)                                     
data["Die Size (mm^2)"] = data["Die Size (mm^2)"].astype(int)

# %%
data["Transistors (million)"] = data["Transistors (million)"].replace("unknown",np.nan)
data["Transistors (million)"] = pd.to_numeric(data["Transistors (million)"], errors="coerce") # Remove non-numeric values and replace them with NaN
data["Transistors (million)"] = data["Transistors (million)"].fillna(0)                                     
data["Transistors (million)"] = data["Transistors (million)"].astype(int)

# %%
data["Foundry"] = data["Foundry"].fillna("UnKnown")

# %% [markdown]
# ## Missing values in Freq (GHz)

# %%
freq_distribution = data["Freq (GHz)"].value_counts(normalize=True) #Calculate the frequency distribution of existing data
#Generate random frequencies based on this distribution
random_freq = np.random.choice(freq_distribution.index, size=data["Freq (GHz)"].isnull().sum(), p=freq_distribution.values)
data.loc[data["Freq (GHz)"].isnull(), "Freq (GHz)"] = random_freq  #Filling in the missing values with random frequencies

# %% [markdown]
# ### testing freq

# %%
n = len(random_freq)
print(n)
# Out:
# 437

# %%
m = len(freq_distribution)
print(m)
# Out:
# 540

# %%
freq_distribution
# Out:
# Freq (GHz)
# 2000.0    0.034383
# 2400.0    0.029947
# 300.0     0.029503
# 2200.0    0.026398
# 2800.0    0.025067
#             ...
# 834.0     0.000222
# 1862.0    0.000222
# 1071.0    0.000222
# 1176.0    0.000222
# 2295.0    0.000222
# Name: proportion, Length: 540, dtype: float64

# %% [markdown]
# ### Missing values in FP16 GFLOPS

# %%
data["FP16 GFLOPS"] = data["FP16 GFLOPS"].fillna(0)

# %% [markdown]
# ### Missing values in FP32 GFLOPS

# %%
data["FP32 GFLOPS"] = data["FP32 GFLOPS"].fillna(0)

# %% [markdown]
# ### Missing values in FP64 GFLOPS

# %%
data["FP64 GFLOPS"] = data["FP64 GFLOPS"].fillna(0)

# %% [markdown]
# ## Perfom a full EDA and demonstrate the validity of the following assumptions

# %% [markdown]
# 1. Moore's Law still holds, especially in GPUs.

# %%
gpu = data[data["Type"] == "GPU"]

# %%
cpu = data[data["Type"] == "CPU"]

# %%
#gpu.head()

# %%
gpu_sort = gpu.sort_values(by = "Release Date")

# %%
plt.figure(figsize=(12, 6))
plt.plot(gpu_sort["Release Date"], gpu_sort["Transistors (million)"])
plt.xlabel("Release Date")
plt.ylabel("Transistors (million)")
plt.title("Trend of Transistors in GPUs over Time")
plt.xticks(rotation=45)
plt.grid(True)

# %%
#since there is an increase in transinstor over time then moore's law holds

# %% [markdown]
# 2. Dannard Scaling is still valid in general.

# %%
plt.figure(figsize=(14, 6))

# Plot 1: Trend of Die Size over time
plt.scatter(cpu["Release Date"], cpu["Die Size (mm^2)"], label="CPU", color="blue")
plt.scatter(gpu["Release Date"], gpu["Die Size (mm^2)"], label="GPU", color="red")
plt.xlabel("Release Date")
plt.ylabel("Die Size (mm^2)")
plt.title("Trend of Die Size over Time")
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Plot 2: Trend of Frequency over time
plt.figure(figsize=(14, 6))
plt.scatter(cpu["Release Date"], cpu["Freq (GHz)"], label="CPU", color="blue")
plt.scatter(gpu["Release Date"], gpu["Freq (GHz)"], label="GPU", color="red")
plt.xlabel("Release Date")
plt.ylabel("Frequency (GHz)")
plt.title("Trend of Frequency over Time")
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# CPUs have higher frequencies, but GPUs are catching up.

# %% [markdown]
# GPU performance doubles every 1.5 years.

# %% [markdown]
# GPU performance improvement is a joint effect of smaller transistors, larger die size, and higher frequency.

# %% [markdown]
# ## Calculate and visualized the correlation among the features

# %%
numeric_data = data[["Process Size (nm)","TDP (W)","Die Size (mm^2)","Transistors (million)","Freq (GHz)",
                     "FP16 GFLOPS","FP32 GFLOPS","FP64 GFLOPS" ]]
correlation_matrix = numeric_data.corr()

# %%
#numeric_data.info()

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Perfom the correct encoding for your data, in readiness for modelling.

# %%
# Encoding 

le = LabelEncoder()
cat_encoded = data[categorical_cols].apply(le.fit_transform)

# %%
cat_encoded.head()
# Out:
#    Product  Type  Process Size (nm)  Foundry  Vendor
# 0      102     0                 23       10       1
# 1      102     0                 23       10       1
# 2      103     0                 23       10       1
# 3      104     0                 23       10       1
# 4      105     0                 23       10       1

# %%
numeric_data.head()
# Out:
#    Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 0                180       54              120                     37
# 1                180       54              120                     37
# 2                180       60              120                     37
# 3                180       63              120                     37
# 4                180       66              120                     37
#
#    Freq (GHz)  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0      1000.0          0.0          0.0          0.0
# 1      1000.0          0.0          0.0          0.0
# 2      1100.0          0.0          0.0          0.0
# 3      1133.0          0.0          0.0          0.0
# 4      1200.0          0.0          0.0          0.0

# %%
# combine the two datasets after scaling
df1 = pd.concat([cat_encoded,numeric_data],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4945 entries, 0 to 4944
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product                4945 non-null   int32
#  1   Type                   4945 non-null   int32
#  2   Process Size (nm)      4945 non-null   int64
#  3   Foundry                4945 non-null   int32
#  4   Vendor                 4945 non-null   int32
#  5   Process Size (nm)      4945 non-null   int32
#  6   TDP (W)                4945 non-null   int32
#  7   Die Size (mm^2)        4945 non-null   int32
#  8   Transistors (million)  4945 non-null   int32
#  9   Freq (GHz)             4945 non-null   float64
#  10  FP16 GFLOPS            4945 non-null   float64
#  11  FP32 GFLOPS            4945 non-null   float64
#  12  FP64 GFLOPS            4945 non-null   float64
# dtypes: float64(4), int32(8), int64(1)
# memory usage: 347.8 KB

# %%
## Data Separation into the X and y matrices
X = df1.drop("Type",axis=1)
y =df1["Type"]

# %%
# Scaling 
scaler = RobustScaler()
X = pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
# separate training and test sets 
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3, random_state=40)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3461, 12) (1484, 12) (3461,) (1484,)

# %%
# fitting a simple linear regression model 
model_reg = LinearRegression()
model_reg.fit(X_train,y_train)
y_hat = model_reg.predict(X_test)
r2_score(y_test,y_hat)
# Out:
# 0.6538626065425874

# %%
# fitting a random forest regression model 
model_reg = RandomForestRegressor(n_estimators=1000)
model_reg.fit(X_train,y_train)
y_hat = model_reg.predict(X_test)
r2_score(y_test,y_hat)
# Out:
# 0.9988286254658694

# %% [markdown]
# - Random forest regration did a better job than linear regration model.
